# %%
from lib.crypto.csprng import *
import matplotlib.pyplot as plt
from random import random, SystemRandom
from lib.crypto.aes import *
import numpy as np

# %% [markdown]
# ## Python Secure Random (Float Mode)

# %%
x = SystemRandom()

# %%
value = []

for i in range(1_000_000):
  value.append(x.random())

plt.hist(value)
# Out:
# (array([100012.,  99957.,  99640., 100197., 100591.,  99696.,  99706.,
#         100159.,  99728., 100314.]),
#  array([1.83205750e-06, 1.00001639e-01, 2.00001445e-01, 3.00001252e-01,
#         4.00001059e-01, 5.00000865e-01, 6.00000672e-01, 7.00000478e-01,
#         8.00000285e-01, 9.00000092e-01, 9.99999898e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([101623.,  97569., 101233.,  97831., 102164.,  97347., 101285.,
#          97800., 101185., 101963.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20310.,  60556.,  99609., 139703., 179014., 179579., 140829.,
#          99803.,  60043.,  20553.]),
#  array([-9.99288131e-01, -7.99507707e-01, -5.99727283e-01, -3.99946859e-01,
#         -2.00166435e-01, -3.86010762e-04,  1.99394413e-01,  3.99174837e-01,
#          5.98955261e-01,  7.98735685e-01,  9.98516109e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Python Secure Random (Integer Mode)

# %%
x = SystemRandom()
value = []

for i in range(1_000_000):
  value.append(x.randint(0, 255))

plt.hist(value)
# Out:
# (array([101174.,  97826., 101524.,  97507., 101230.,  97668., 101513.,
#          98336., 101055., 102167.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20374.,  59707.,  99436., 139731., 178861., 180036., 139700.,
#         100221.,  60967.,  20966.]),
#  array([-255., -204., -153., -102.,  -51.,    0.,   51.,  102.,  153.,
#          204.,  255.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Henon Map

# %%
x = HenonMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 30813.,  52779.,  79392., 100919.,  84623.,  85220.,  99021.,
#         122628., 193138., 151467.]),
#  array([-1.86998555, -1.48844836, -1.10691117, -0.72537398, -0.34383679,
#          0.0377004 ,  0.41923759,  0.80077477,  1.18231196,  1.56384915,
#          1.94538634]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([ 75921.,  79404.,  95978., 106035., 119496., 136325., 129925.,
#          98053.,  85622.,  73241.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 10143.,  63074., 108398., 157421., 189836., 191715., 117394.,
#          94378.,  58056.,   9584.]),
#  array([-3.60062764, -2.86302614, -2.12542463, -1.38782312, -0.65022162,
#          0.08737989,  0.8249814 ,  1.5625829 ,  2.30018441,  3.03778592,
#          3.77538742]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Thomas Attractor Map

# %%
x = ThomasAttractorMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([222222.,  90440.,  69434.,  60645.,  57258.,  57254.,  60648.,
#          69434.,  90443., 222222.]),
#  array([-9.84974981e-01, -7.87979985e-01, -5.90984989e-01, -3.93989993e-01,
#         -1.96994996e-01, -4.01123579e-13,  1.96994996e-01,  3.93989993e-01,
#          5.90984989e-01,  7.87979985e-01,  9.84974981e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([205402.,  94172.,  74723.,  64980.,  60721.,  60724.,  64978.,
#          74727.,  94169., 205403.]),
#  array([-1.82384848e+00, -1.45907878e+00, -1.09430909e+00, -7.29539390e-01,
#         -3.64769695e-01, -1.18394183e-12,  3.64769695e-01,  7.29539390e-01,
#          1.09430909e+00,  1.45907878e+00,  1.82384848e+00]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Logistic Map

# %%
x = LogisticMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([204491.,  90483.,  73823.,  67066.,  64074.,  64252.,  66624.,
#          74056.,  90397., 204734.]),
#  array([1.9180213e-12, 1.0000000e-01, 2.0000000e-01, 3.0000000e-01,
#         4.0000000e-01, 5.0000000e-01, 6.0000000e-01, 7.0000000e-01,
#         8.0000000e-01, 9.0000000e-01, 1.0000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([114746.,  50688.,  41567.,  38207.,  36308.,  36717., 154204.,
#         127490., 130433., 269639.]),
#  array([-1.     , -0.84375, -0.6875 , -0.53125, -0.375  , -0.21875,
#         -0.0625 ,  0.09375,  0.25   ,  0.40625,  0.5625 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Sine Henon Map

# %%
x = SineHenonMap(random(), random())

value = []
for i in range(1_000_000):
  val = x.get_value()
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([100116., 100083.,  99673.,  99415.,  99799., 100258., 100246.,
#         100194., 100412.,  99804.]),
#  array([2.14465561e-06, 1.00001900e-01, 2.00001655e-01, 3.00001410e-01,
#         4.00001165e-01, 5.00000921e-01, 6.00000676e-01, 7.00000431e-01,
#         8.00000186e-01, 8.99999941e-01, 9.99999696e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20028.,  60452., 100137., 139842., 178869., 180391., 139767.,
#         100048.,  60303.,  20162.]),
#  array([-9.99040115e-01, -7.99263681e-01, -5.99487248e-01, -3.99710815e-01,
#         -1.99934382e-01, -1.57948256e-04,  1.99618485e-01,  3.99394918e-01,
#          5.99171352e-01,  7.98947785e-01,  9.98724218e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([101624.,  97706., 101207.,  97140., 101384.,  97813., 101902.,
#          97770., 101989., 101465.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
