# %%
from chaos import *
import matplotlib.pyplot as plt
from random import random, SystemRandom
from util import *
import numpy as np

# %% [markdown]
# ## Python Secure Random (Float Mode)

# %%
x = SystemRandom()

# %%
value = []

for i in range(1_000_000):
  value.append(x.random())

plt.hist(value)
# Out:
# (array([100209.,  99751.,  99917., 100162., 100077.,  99729., 100006.,
#          99931.,  99894., 100324.]),
#  array([4.34271294e-07, 1.00000303e-01, 2.00000173e-01, 3.00000042e-01,
#         3.99999911e-01, 4.99999780e-01, 5.99999649e-01, 6.99999518e-01,
#         7.99999388e-01, 8.99999257e-01, 9.99999126e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20138.,  60471.,  99905., 139898., 179875., 179365., 139700.,
#         100073.,  60182.,  20392.]),
#  array([-9.98169185e-01, -7.98532164e-01, -5.98895143e-01, -3.99258123e-01,
#         -1.99621102e-01,  1.59194231e-05,  1.99652940e-01,  3.99289961e-01,
#          5.98926982e-01,  7.98564003e-01,  9.98201024e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Python Secure Random (Integer Mode)

# %%
x = SystemRandom()
value = []

for i in range(1_000_000):
  value.append(x.randint(0, 255))

plt.hist(value)
# Out:
# (array([101278.,  97625., 101315.,  97726., 101526.,  98375., 101476.,
#          97543., 101990., 101146.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20067.,  59682.,  99753., 139268., 179127., 180175., 140314.,
#         100411.,  60400.,  20802.]),
#  array([-255., -204., -153., -102.,  -51.,    0.,   51.,  102.,  153.,
#          204.,  255.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Henon Map

# %%
x = HenonMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 31203.,  52997.,  79920., 100241.,  84957.,  85081.,  99195.,
#         122000., 193015., 151391.]),
#  array([-1.86835946, -1.48695019, -1.10554092, -0.72413164, -0.34272237,
#          0.0386869 ,  0.42009617,  0.80150544,  1.18291471,  1.56432398,
#          1.94573325]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([ 31528.,  52003.,  82059.,  98553.,  83622.,  87057.,  97511.,
#         125012., 189860., 152795.]),
#  array([  8. ,  32.4,  56.8,  81.2, 105.6, 130. , 154.4, 178.8, 203.2,
#         227.6, 252. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 10219.,  63449., 107697., 157171., 189255., 191522., 118645.,
#          94171.,  58087.,   9783.]),
#  array([-3.60246782, -2.86487333, -2.12727884, -1.38968435, -0.65208986,
#          0.08550463,  0.82309911,  1.5606936 ,  2.29828809,  3.03588258,
#          3.77347707]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Thomas Attractor Map

# %%
x = ThomasAttractorMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([222224.,  90442.,  69421.,  60651.,  57258.,  57263.,  60654.,
#          69420.,  90444., 222223.]),
#  array([-9.84974981e-01, -7.87979985e-01, -5.90984989e-01, -3.93989993e-01,
#         -1.96994996e-01,  1.41886503e-13,  1.96994996e-01,  3.93989993e-01,
#          5.90984989e-01,  7.87979985e-01,  9.84974981e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([205401.,  94167.,  74725.,  64988.,  60717.,  60721.,  64987.,
#          74720.,  94173., 205400.]),
#  array([-1.82384848e+00, -1.45907878e+00, -1.09430909e+00, -7.29539390e-01,
#         -3.64769695e-01,  6.33604280e-12,  3.64769695e-01,  7.29539390e-01,
#          1.09430909e+00,  1.45907878e+00,  1.82384848e+00]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Logistic Map

# %%
x = LogisticMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([205220.,  90371.,  73738.,  66869.,  63892.,  64450.,  66740.,
#          73717.,  90185., 204818.]),
#  array([2.50466314e-11, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([114662.,  50824.,  41610.,  37829.,  36636.,  36540., 154331.,
#         127645., 130316., 269606.]),
#  array([-1.     , -0.84375, -0.6875 , -0.53125, -0.375  , -0.21875,
#         -0.0625 ,  0.09375,  0.25   ,  0.40625,  0.5625 ]),
#  <BarContainer object of 10 artists>)
