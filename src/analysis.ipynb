# %%
from lib.crypto.csprng import *
import matplotlib.pyplot as plt
from random import random, SystemRandom
from lib.crypto.aes import *
import numpy as np

# %% [markdown]
# ## Python Secure Random (Float Mode)

# %%
x = SystemRandom()

# %%
value = []

for i in range(1_000_000):
  value.append(x.random())

plt.hist(value)
# Out:
# (array([ 99960.,  99854., 100311.,  99911.,  99931.,  99735., 100194.,
#         100196., 100520.,  99388.]),
#  array([1.01377534e-07, 1.00000009e-01, 1.99999918e-01, 2.99999826e-01,
#         3.99999734e-01, 4.99999642e-01, 5.99999550e-01, 6.99999458e-01,
#         7.99999366e-01, 8.99999274e-01, 9.99999182e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist([to_linear(i) for i in value])
# Out:
# (array([ 99960.,  99854., 100311.,  99911.,  99931.,  99735., 100194.,
#         100196., 100520.,  99388.]),
#  array([4.35000000e+02, 4.29496770e+08, 8.58993105e+08, 1.28848944e+09,
#         1.71798577e+09, 2.14748211e+09, 2.57697844e+09, 3.00647478e+09,
#         3.43597111e+09, 3.86546745e+09, 4.29496378e+09]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 19980.,  60301., 100073., 140085., 179153., 180069., 139988.,
#          99857.,  60427.,  20066.]),
#  array([-9.98849321e-01, -7.99088899e-01, -5.99328478e-01, -3.99568056e-01,
#         -1.99807634e-01, -4.72124454e-05,  1.99713209e-01,  3.99473631e-01,
#          5.99234053e-01,  7.98994474e-01,  9.98754896e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Python Secure Random (Integer Mode)

# %%
x = SystemRandom()
value = []

for i in range(1_000_000):
  value.append(x.randint(0, 255))

plt.hist(value)
# Out:
# (array([101204.,  97872., 101948.,  97768., 101725.,  97441., 101638.,
#          97481., 101451., 101472.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20198.,  59775.,  99612., 139465., 178742., 180052., 140329.,
#         100338.,  60486.,  21002.]),
#  array([-255., -204., -153., -102.,  -51.,    0.,   51.,  102.,  153.,
#          204.,  255.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Henon Map

# %%
x = HenonMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 30995.,  52959.,  79240., 101409.,  84859.,  85362.,  98723.,
#         121096., 193942., 151415.]),
#  array([-1.86877429, -1.48738114, -1.10598798, -0.72459482, -0.34320167,
#          0.03819149,  0.41958464,  0.8009778 ,  1.18237095,  1.56376411,
#          1.94515726]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter([i for i in range(len(value))],value)

# %%
plt.hist(to_linear(value))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.hist(to_linear(value))
#
# File ~/Documents/TA/ta-code/src/lib/util.py:6, in to_linear(x, size)
#       4 def to_linear(x, *, size=32):
#       5     result = 0
# ----> 6     i = x % 1
#       8     for _ in range(size):
#       9         result <<= 1
#
# TypeError: unsupported operand type(s) for %: 'list' and 'int'

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 10130.,  63117., 108549., 156949., 189346., 191737., 118120.,
#          94148.,  58110.,   9793.]),
#  array([-3.60226755, -2.86461043, -2.1269533 , -1.38929618, -0.65163905,
#          0.08601807,  0.8236752 ,  1.56133232,  2.29898945,  3.03664657,
#          3.7743037 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Thomas Attractor Map

# %%
x = ThomasAttractorMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([222210.,  90454.,  69428.,  60648.,  57254.,  57258.,  60655.,
#          69431.,  90448., 222214.]),
#  array([-9.84974981e-01, -7.87979985e-01, -5.90984989e-01, -3.93989993e-01,
#         -1.96994996e-01,  2.01538786e-12,  1.96994996e-01,  3.93989993e-01,
#          5.90984989e-01,  7.87979985e-01,  9.84974981e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([205404.,  94161.,  74726.,  64978.,  60731.,  60727.,  64983.,
#          74721.,  94164., 205404.]),
#  array([-1.82384848e+00, -1.45907878e+00, -1.09430909e+00, -7.29539390e-01,
#         -3.64769695e-01,  1.89559479e-12,  3.64769695e-01,  7.29539390e-01,
#          1.09430909e+00,  1.45907878e+00,  1.82384848e+00]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Logistic Map

# %%
x = LogisticMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([205385.,  89995.,  73924.,  67029.,  64217.,  64052.,  66838.,
#          73363.,  90424., 204773.]),
#  array([3.68594044e-14, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([114587.,  50657.,  41987.,  37756.,  36643.,  36608., 154391.,
#         127224., 130553., 269593.]),
#  array([-1.     , -0.84375, -0.6875 , -0.53125, -0.375  , -0.21875,
#         -0.0625 ,  0.09375,  0.25   ,  0.40625,  0.5625 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Sine Henon Map

# %%
x = SineHenonMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_value()
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 99954.,  99967., 100091., 100322.,  99635., 100040., 100103.,
#         100301., 100108.,  99479.]),
#  array([1.08700237e-06, 1.00000588e-01, 2.00000089e-01, 2.99999590e-01,
#         3.99999092e-01, 4.99998593e-01, 5.99998094e-01, 6.99997595e-01,
#         7.99997096e-01, 8.99996597e-01, 9.99996098e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter([i for i in range(len(value))],value)

# %%
plt.plot(value[:200])

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20168.,  60237., 100192., 139918., 179296., 180084., 139995.,
#         100073.,  60091.,  19945.]),
#  array([-9.98661261e-01, -7.98878323e-01, -5.99095385e-01, -3.99312447e-01,
#         -1.99529508e-01,  2.53429591e-04,  2.00036368e-01,  3.99819306e-01,
#          5.99602244e-01,  7.99385182e-01,  9.99168120e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([101420.,  97561., 101402.,  97622., 102022.,  97605., 101516.,
#          97655., 101622., 101575.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
