# %%
from lib.crypto.csprng import *
import matplotlib.pyplot as plt
from random import random, SystemRandom
from lib.crypto.aes import *
import numpy as np

# %% [markdown]
# ## Python Secure Random (Float Mode)

# %%
x = SystemRandom()

# %%
value = []

for i in range(1_000_000):
  value.append(x.random())

plt.hist(value)
# Out:
# (array([100215.,  99646.,  99805.,  99832., 100468.,  99723.,  99903.,
#          99734., 100356., 100318.]),
#  array([6.03167610e-07, 1.00000505e-01, 2.00000406e-01, 3.00000308e-01,
#         4.00000209e-01, 5.00000111e-01, 6.00000012e-01, 6.99999914e-01,
#         7.99999815e-01, 8.99999717e-01, 9.99999618e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([101774.,  97317., 101364.,  97495., 102016.,  97353., 101461.,
#          97374., 102002., 101844.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20281.,  60329., 100065., 140212., 179410., 179218., 139988.,
#         100116.,  60192.,  20188.]),
#  array([-9.98610881e-01, -7.98834467e-01, -5.99058054e-01, -3.99281641e-01,
#         -1.99505228e-01,  2.71185755e-04,  2.00047599e-01,  3.99824012e-01,
#          5.99600426e-01,  7.99376839e-01,  9.99153252e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Python Secure Random (Integer Mode)

# %%
x = SystemRandom()
value = []

for i in range(1_000_000):
  value.append(x.randint(0, 255))

plt.hist(value)
# Out:
# (array([101407.,  97939., 102270.,  97491., 101774.,  97330., 101681.,
#          97685., 101490., 100933.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 19903.,  59926.,  99524., 139614., 179308., 179716., 140841.,
#          99609.,  60374.,  21184.]),
#  array([-255., -204., -153., -102.,  -51.,    0.,   51.,  102.,  153.,
#          204.,  255.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Henon Map

# %%
x = HenonMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 31099.,  53191.,  79349., 101075.,  84598.,  85292.,  99225.,
#         121595., 193497., 151079.]),
#  array([-1.86826238, -1.48685338, -1.10544437, -0.72403537, -0.34262637,
#          0.03878263,  0.42019163,  0.80160064,  1.18300964,  1.56441864,
#          1.94582764]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([ 76591.,  79201.,  95993., 106750., 120282., 136880., 128815.,
#          98027.,  85421.,  72040.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 10130.,  63117., 108549., 156949., 189346., 191737., 118120.,
#          94148.,  58110.,   9793.]),
#  array([-3.60226755, -2.86461043, -2.1269533 , -1.38929618, -0.65163905,
#          0.08601807,  0.8236752 ,  1.56133232,  2.29898945,  3.03664657,
#          3.7743037 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Thomas Attractor Map

# %%
x = ThomasAttractorMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([222210.,  90454.,  69428.,  60648.,  57254.,  57258.,  60655.,
#          69431.,  90448., 222214.]),
#  array([-9.84974981e-01, -7.87979985e-01, -5.90984989e-01, -3.93989993e-01,
#         -1.96994996e-01,  2.01538786e-12,  1.96994996e-01,  3.93989993e-01,
#          5.90984989e-01,  7.87979985e-01,  9.84974981e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([205404.,  94161.,  74726.,  64978.,  60731.,  60727.,  64983.,
#          74721.,  94164., 205404.]),
#  array([-1.82384848e+00, -1.45907878e+00, -1.09430909e+00, -7.29539390e-01,
#         -3.64769695e-01,  1.89559479e-12,  3.64769695e-01,  7.29539390e-01,
#          1.09430909e+00,  1.45907878e+00,  1.82384848e+00]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Logistic Map

# %%
x = LogisticMap(random(), random(), random())

value = []
for i in range(1_000_000):
  val = x.get_tuple()[0]
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([205087.,  90205.,  73778.,  67253.,  63936.,  64168.,  66706.,
#          73379.,  90510., 204978.]),
#  array([1.04849462e-12, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([114587.,  50657.,  41987.,  37756.,  36643.,  36608., 154391.,
#         127224., 130553., 269593.]),
#  array([-1.     , -0.84375, -0.6875 , -0.53125, -0.375  , -0.21875,
#         -0.0625 ,  0.09375,  0.25   ,  0.40625,  0.5625 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Sine Henon Map

# %%
x = SineHenonMap(random(), random())

value = []
for i in range(1_000_000):
  val = x.get_value()
  value.append(val)

  x = x.next()

plt.hist(value)
# Out:
# (array([ 99991.,  99905., 100113.,  99947., 100306.,  99886.,  99903.,
#          99604., 100176., 100169.]),
#  array([7.46605764e-07, 1.00000651e-01, 2.00000556e-01, 3.00000460e-01,
#         4.00000365e-01, 5.00000270e-01, 6.00000174e-01, 7.00000079e-01,
#         7.99999983e-01, 8.99999888e-01, 9.99999792e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.diff(value))
# Out:
# (array([ 20274.,  60372.,  99787., 139971., 179499., 179370., 140250.,
#         100111.,  60250.,  20115.]),
#  array([-9.99352995e-01, -7.99486422e-01, -5.99619849e-01, -3.99753276e-01,
#         -1.99886702e-01, -2.01288491e-05,  1.99846444e-01,  3.99713018e-01,
#          5.99579591e-01,  7.99446164e-01,  9.99312738e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(to_linear(value))
# Out:
# (array([101578.,  97503., 101751.,  97532., 101898.,  97515., 101481.,
#          97286., 101726., 101730.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
